# %%
from ipywidgets import interact, fixed, IntSlider, widgets
import matplotlib.pyplot as plt
import numpy as np
import tifffile
from pathlib import Path

# %%
def add(x,y):
    return x + y

interact(
    add,
    x=3,
    y=5
)
# Out:
# interactive(children=(IntSlider(value=3, description='x', max=9, min=-3), IntSlider(value=5, description='y', …
# <function __main__.add>

# %%
mov = np.random.normal(0,2, size=(300,300,100))

# %%
@interact(
    idx = IntSlider(value=0, min=0, max=mov.shape[2] -1)
)
def show(idx):
    plt.imshow(mov[:,:,idx])
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=99), Output()), _dom_classes=('widget-interact…

# %%
Path.home()
filepath = Path('../../data/raw')
files = list(filepath.glob('*.tif'))

# %%
data = tifffile.TiffSequence(files[:100]).asarray()

# %%
@interact(
    data = IntProgress(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Loading:',
    bar_style='', # 'success', 'info', 'warning', 'danger' or ''
    orientation='horizontal'
)

def load_data(files):
    data = tifffile.TiffSequence(files[:10]).asarray()
    return data

# %%
data.shape
# Out:
# (1000, 498, 467)

# %%
plt.imshow(data[3])

# %%
@interact(
    idx = IntSlider(value=0, min=0, max=data.shape[0]-1)
)
def show(idx):
    plt.imshow(data[idx,:,:])
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=999), Output()), _dom_classes=('widget-interac…

# %%
@interact(
    idx = IntSlider(
        description='Frame index:',
        value=0,
        min=0,
        max=data.shape[0]-1,
        disabled = True,
        continuous_update = True
    )
)
def show(idx):
    plt.imshow(data[idx,:,:])
# Out:
# interactive(children=(IntSlider(value=0, description='Frame index:', disabled=True, max=999), Output()), _dom_…

# %%
@interact(
    idx = IntSlider(
        description='frame idx:',
        value=0,
        min=0,
        max=data.shape[0]-1,
        step = 1,
        orientation = "horizontal",
        continuous_update = True
    )
)
def show(idx):
    plt.imshow(data[idx,:,:])

widgets.Text(
    value=' ',
    placeholder='Type something',
    description='Pick a frame',
    disabled=False
)
# Out:
# interactive(children=(IntSlider(value=0, description='frame idx:', max=99), Output()), _dom_classes=('widget-i…
# Text(value=' ', description='Pick a frame', placeholder='Type something')

# %%
accordion = widgets.Accordion(children=[widgets.IntSlider(), widgets.Text()])
accordion.set_title(0, 'Slider')
accordion.set_title(1, 'Text')
accordion

# %%
widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='pink',
    disabled=False
)
# Out:
# ColorPicker(value='pink', description='Pick a color')

# %%
widgets.Text(
    value=' ',
    placeholder='Type something',
    description='Pick a frame',
    disabled=False
)
# Out:
# Text(value=' ', description='Pick a frame', placeholder='Type something')

# %%
@interact(
        ,
    idx = IntSlider(
        description='frame idx:',
        value=0,
        min=0,
        max=data.shape[0]-1,
        step = 1,
        orientation = "horizontal",
        continuous_update = True)
)
def show(idx):
       plt.imshow(data[idx,:,:])
# Out:
# interactive(children=(IntSlider(value=0, description='frame idx:', max=99), Output()), _dom_classes=('widget-i…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-ce9baf9574b2> in <module>()
#      12         step = 1,
#      13         orientation = "horizontal",
# ---> 14         continuous_update = True)
#      15 )
#      16 def show(idx):
#
# TypeError: 'ColorPicker' object is not callable

# %%
widgets.ColorPicker(
        concise=False,
        description='Pick a color',
        value='pink',
        disabled=False)
# Out:
# ColorPicker(value='pink', description='Pick a color')

# %%
def show(idx, cmap):
       plt.imshow(data[idx,:,:], cmap = cmap)
       print(idx)

play = widgets.Play(
#     interval=10,
    value=50,
    min=0,
    max=1,
    step=1,
    description="Press play",
    disabled=False
)

framepicker = widgets.IntText(
    value=7,
    description='Any:',
    disabled=False
)

interact(show, idx=framepicker, cmap = ["gray", "summer"])
# Out:
# interactive(children=(IntText(value=7, description='Any:'), Dropdown(description='cmap', options=('gray', 'sum…
# <function __main__.show>

# %%
widgets.IntText(
    value=7,
    description='Any:',
    disabled=False
)
